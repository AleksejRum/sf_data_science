# %% [markdown]
# ### Work with txt_read and read_table

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly
import plotly.express as px

countries_data = pd.read_csv('data/countries.csv', sep=';') 
countries_data.to_csv('data/countries.txt',sep=' ',index=False)

tx_df = pd.read_table('data/countries.txt',sep=' ',index_col=['country'])
display(tx_df)
# Out:
#            population    square
# country
# Англия          56.29    133396
# Канада          38.05   9984670
# США            322.28   9826630
# Россия         146.24  17125191
# Украина         45.50    603628
# Беларусь         9.50    207600
# Казахстан       17.04   2724902

# %% [markdown]
# ### Applying the header parameter

# %%
melb_data = pd.read_csv('data/melb_data_ps.csv',header=None)

display(melb_data.head(3))
# Out:
#       0           1                2      3     4          5       6   \
# 0  index      Suburb          Address  Rooms  Type      Price  Method
# 1      0  Abbotsford     85 Turner St      2     h  1480000.0       S
# 2      1  Abbotsford  25 Bloomburg St      2     h  1035000.0       S
#
#         7          8         9   ...   13        14            15         16  \
# 0  SellerG       Date  Distance  ...  Car  Landsize  BuildingArea  YearBuilt
# 1   Biggin  3/12/2016       2.5  ...    1     202.0         126.0       1970
# 2   Biggin  4/02/2016       2.5  ...    0     156.0          79.0       1900
#
#             17         18          19                     20             21  \
# 0  CouncilArea  Lattitude  Longtitude             Regionname  Propertycount
# 1        Yarra   -37.7996    144.9984  Northern Metropolitan           4019
# 2        Yarra   -37.8079    144.9934  Northern Metropolitan           4019
#
#                    22
# 0         Coordinates
# ...

# %% [markdown]
# ### Problems with encoding of the source data

# %%
# Считываем данные из файла с неизвестной кодировкой в переменную, создавая объект DataFrame
data = pd.read_csv('data/ErrorEnCoding.csv', header=None)
display(data)
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# c:\IDE\Modules\Pandas\PY_16_Upload_files\Upload_files.ipynb Ячейка 6 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/c%3A/IDE/Modules/Pandas/PY_16_Upload_files/Upload_files.ipynb#ch0000004?line=0'>1</a> # Считываем данные из файла с неизвестной кодировкой в переменную, создавая объект DataFrame
# ----> <a href='vscode-notebook-cell:/c%3A/IDE/Modules/Pandas/PY_16_Upload_files/Upload_files.ipynb#ch0000004?line=1'>2</a> data = pd.read_csv('data/ErrorEnCoding.csv', header=None)
#       <a href='vscode-notebook-cell:/c%3A/IDE/Modules/Pandas/PY_16_Upload_files/Upload_files.ipynb#ch0000004?line=2'>3</a> display(data)
#
# File c:\Users\Алексей\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
# ...
